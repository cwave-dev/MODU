# %% [markdown]
# <a href="https://colab.research.google.com/github/cwave-dev/MODU/blob/main/map_visualization_baby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install geopandas

from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import geopandas as gpd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
from shapely.geometry import Polygon, Point
import json

# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 26.3 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 31.6 MB/s
# ...
# Mounted at /content/drive

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')
# Out:
# Unknown system... sorry~~~~

# %%
df = pd.read_csv('/content/drive/MyDrive/데이터포럼/Toilet_Data/서울교통공사_역사공중화장실정보_20220331.csv', encoding='cp949')
print(df.head(5))
# Out:
#            x           y        place
# 0  37.556878  126.972578  남자화장실,여자화장실
# 1  37.565682  126.976849  남자화장실,여자화장실
# 2  37.570175  126.983226  남자화장실,여자화장실
# 3  37.570384  126.992008  남자화장실,여자화장실
# 4  37.570384  126.992008  남자화장실,여자화장실

# %%
w = []
m = []
b = []

for i in range(len(df['place'])):
    tmp = []
    if (df['place'][i] == "여자화장실"):
        tmp.append(df['x'][i])
        tmp.append(df['y'][i])
        tmp.append(df['place'][i])
        w.append(tmp)
    if (df['place'][i] == "남자화장실"):
        tmp.append(df['x'][i])
        tmp.append(df['y'][i])
        tmp.append(df['place'][i])
        m.append(tmp)
    if (df['place'][i] == "남자화장실,여자화장실"):
        tmp.append(df['x'][i])
        tmp.append(df['y'][i])
        tmp.append(df['place'][i])
        b.append(tmp)
    else:
      pass
print(len(w))
print(len(m))
print(len(b))
print(len(b))
# Out:
# 34
# 0
# 257

# %%
# 기저귀 교환대가 여자화장실 둘 다에 있는 경우

map_osm = folium.Map(location=[37.56, 126.97],zoom_start=11)

for i in range(len(w)):
     folium.Marker([float(w[i][0]),float(w[i][1])], popup='여자화장실', icon=folium.Icon(color='red', icon='info-sign')).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 기저귀 교환대가 남자화장실에 있는 경우

map_osm = folium.Map(location=[37.56, 126.97],zoom_start=11)

for i in range(len(m)):
     folium.Marker([float(m[i][0]),float(m[i][1])], popup='남자화장실', icon=folium.Icon(color='blue', icon='info-sign')).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 기저귀 교환대가 남자화장실, 여자화장실 둘 다에 있는 경우

map_osm = folium.Map(location=[37.56, 126.97],zoom_start=11)

for i in range(len(w)):
     folium.Marker([float(w[i][0]),float(w[i][1])], popup='여자화장실', icon=folium.Icon(color='red', icon='info-sign')).add_to(map_osm)

for i in range(len(b)):
     folium.Marker([float(b[i][0]),float(b[i][1])], popup='남자화장실,여자화장실 둘 다', icon=folium.Icon(color='blue', icon='info-sign')).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
